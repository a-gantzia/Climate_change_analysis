# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
# %matplotlib inline
import plotly
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import time
from datetime import datetime
import warnings

warnings.filterwarnings('ignore')
# plotly
# seaborn
# pandas-profiling

# %%
temp_city = pd.read_csv('./input/GlobalLandTemperaturesByCity.csv')
temp_country = pd.read_csv('./input/GlobalLandTemperaturesByCountry.csv')
temp_global = pd.read_csv('./input/GlobalTemperatures.csv')
#temp_city = pd.read_csv('./input/GlobalLandTemperaturesByCity.csv')

# %%
temp_city = temp_city[temp_city['AverageTemperature'].notna()]

# %%
temp_city['dt'] = pd.to_datetime(temp_city['dt'], dayfirst=True)

# %%
temp_city['year'] = temp_city['dt'].dt.year
temp_city['month'] = temp_city['dt'].dt.month
temp_city.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01                6.07                           1.74  Århus
# 5 1744-04-01                5.79                           3.62  Århus
# 6 1744-05-01               10.64                           1.28  Århus
# 7 1744-06-01               14.05                           1.35  Århus
# 8 1744-07-01               16.08                           1.40  Århus
#
#    Country Latitude Longitude  year  month
# 0  Denmark   57.05N    10.33E  1743     11
# 5  Denmark   57.05N    10.33E  1744      4
# 6  Denmark   57.05N    10.33E  1744      5
# 7  Denmark   57.05N    10.33E  1744      6
# 8  Denmark   57.05N    10.33E  1744      7

# %%
temp_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8235082 entries, 0 to 8599210
# Data columns (total 9 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             datetime64[ns]
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
#  7   year                           int64
#  8   month                          int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 628.3+ MB

# %%
temp_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8235082 entries, 0 to 8599210
# Data columns (total 9 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             datetime64[ns]
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
#  7   year                           int64
#  8   month                          int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 628.3+ MB

# %%
temp_city.Country.value_counts()
# Out:
# India               960548
# China               819132
# United States       661524
# Brazil              451645
# Russia              448663
#                      ...
# Burundi               1675
# Eritrea               1669
# Djibouti              1658
# Oman                  1652
# Papua New Guinea      1580
# Name: Country, Length: 159, dtype: int64

# %%
temp_city.shape
# Out:
# (8235082, 9)

# %%
temp_city.isna().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# year                             0
# month                            0
# dtype: int64

# %%
np.set_printoptions(suppress=True)

# %%
temp_city.head(5)
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01                6.07                           1.74  Århus
# 5 1744-04-01                5.79                           3.62  Århus
# 6 1744-05-01               10.64                           1.28  Århus
# 7 1744-06-01               14.05                           1.35  Århus
# 8 1744-07-01               16.08                           1.40  Århus
#
#    Country Latitude Longitude  year  month
# 0  Denmark   57.05N    10.33E  1743     11
# 5  Denmark   57.05N    10.33E  1744      4
# 6  Denmark   57.05N    10.33E  1744      5
# 7  Denmark   57.05N    10.33E  1744      6
# 8  Denmark   57.05N    10.33E  1744      7

# %%
temp_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8235082 entries, 0 to 8599210
# Data columns (total 9 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             datetime64[ns]
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
#  7   year                           int64
#  8   month                          int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 628.3+ MB

# %%
temp_city.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty       year      month
# count          8235082.00                     8235082.00 8235082.00 8235082.00
# mean                16.73                           1.03    1910.83       6.49
# std                 10.35                           1.13      64.20       3.45
# min                -42.70                           0.03    1743.00       1.00
# 25%                 10.30                           0.34    1865.00       3.00
# 50%                 18.83                           0.59    1915.00       6.00
# 75%                 25.21                           1.35    1964.00       9.00
# max                 39.65                          15.40    2013.00      12.00

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
temp_city['temp_top'] = temp_city['AverageTemperature'] + temp_city['AverageTemperatureUncertainty']
temp_city['temp_bottom'] = temp_city['AverageTemperature'] - temp_city['AverageTemperatureUncertainty']

# %%
temp_city.Country.value_counts()
# Out:
# India               960548
# China               819132
# United States       661524
# Brazil              451645
# Russia              448663
#                      ...
# Burundi               1675
# Eritrea               1669
# Djibouti              1658
# Oman                  1652
# Papua New Guinea      1580
# Name: Country, Length: 159, dtype: int64

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(temp_city, title="Pandas Profiling Report", explorative=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Grigoris\anaconda3\lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\Grigoris\anaconda3\lib\multiprocessing\pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "C:\Users\Grigoris\anaconda3\lib\site-packages\pandas_profiling\describe.py", line 282, in multiprocess_func
#     return x[0], describe_1d(x[1], **kwargs)
#   File "C:\Users\Grigoris\anaconda3\lib\site-packages\pandas_profiling\describe.py", line 272, in describe_1d
#     result = result.append(describe_date_1d(data, **kwargs))
# TypeError: describe_date_1d() got an unexpected keyword argument 'title'
# """
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
gr = temp_city[temp_city['Country'] == 'Greece']

# %%
gr.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty     year    month  \
# count            21752.00                       21752.00 21752.00 21752.00
# mean                16.35                           1.43  1883.55     6.49
# std                  6.64                           1.32    74.98     3.45
# min                 -2.28                           0.05  1743.00     1.00
# 25%                 11.12                           0.43  1819.00     3.00
# 50%                 16.17                           0.94  1884.00     6.00
# 75%                 22.56                           2.06  1948.00     9.00
# max                 30.12                           9.57  2013.00    12.00
#
#        temp_top  temp_bottom
# count  21752.00     21752.00
# mean      17.78        14.92
# std        6.58         6.95
# min       -1.67       -11.08
# 25%       12.62         9.55
# 50%       17.67        14.96
# 75%       23.72        21.13
# max       34.50        28.65

# %%
gr = gr[gr['AverageTemperature'].notna()]

# %% [raw]
# gr.info()

# %%
gr.City.value_counts()
# Out:
# Thessaloníki    3166
# Lárisa          3166
# Pátrai          3160
# Kallithéa       3128
# Peristérion     3128
# Athens          3128
# Iráklion        2876
# Name: City, dtype: int64

# %%
gr['year'] = gr['dt'].split('-')[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-693109309344> in <module>
# ----> 1 gr['year'] = gr['dt'].split('-')[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
temp_country = temp_country[temp_country['AverageTemperature'].notna()]

# %%
temp_country.Country.value_counts()
# Out:
# Austria                                3166
# Macedonia                              3166
# Croatia                                3166
# Sweden                                 3166
# Montenegro                             3166
#                                        ...
# Federated States Of Micronesia         1364
# Guam                                   1328
# Northern Mariana Islands               1328
# French Southern And Antarctic Lands     783
# Heard Island And Mcdonald Islands       783
# Name: Country, Length: 242, dtype: int64

# %%
temp_country['dt'] = pd.to_datetime(temp_country['dt'], dayfirst=True)
temp_country['year'] = temp_country['dt'].dt.year
temp_country['month'] = temp_country['dt'].dt.month
temp_country.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty Country  year  \
# 0 1743-11-01                4.38                           2.29   Åland  1743
# 5 1744-04-01                1.53                           4.68   Åland  1744
# 6 1744-05-01                6.70                           1.79   Åland  1744
# 7 1744-06-01               11.61                           1.58   Åland  1744
# 8 1744-07-01               15.34                           1.41   Åland  1744
#
#    month
# 0     11
# 5      4
# 6      5
# 7      6
# 8      7

# %%
temp_global = temp_global[temp_global['LandMaxTemperature'].notna()]
temp_global['dt'] = pd.to_datetime(temp_global['dt'], dayfirst=True)
temp_global['year'] = temp_global['dt'].dt.year
temp_global['month'] = temp_global['dt'].dt.month
temp_global.head()
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200 1850-01-01                    0.75                               1.10
# 1201 1850-02-01                    3.07                               1.27
# 1202 1850-03-01                    4.95                               0.95
# 1203 1850-04-01                    7.22                               0.67
# 1204 1850-05-01                   10.00                               0.62
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 1200                8.24                           1.74               -3.21
# 1201                9.97                           3.01               -2.29
# 1202               10.35                           2.40               -1.91
# 1203               12.93                           1.00                1.02
# 1204               15.65                           2.41                3.81
#
# ...

# %%
#dataset for every city to greece
gr_ath = gr[gr['City'] == 'Athens']
gr_thes = gr[gr['City'] =='Thessaloníki' ]
gr_lar = gr[gr['City'] == 'Lárisa']
gr_patra = gr[gr['City'] == 'Pátrai']

# %%
gr_ath
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 460994 1753-01-01                8.77                           5.13  Athens
# 460995 1753-02-01                8.46                           2.93  Athens
# 460996 1753-03-01               12.95                           2.76  Athens
# 460997 1753-04-01               14.96                           4.85  Athens
# 460998 1753-05-01               20.14                           2.03  Athens
# ...           ...                 ...                            ...     ...
# 464117 2013-04-01               16.95                           0.29  Athens
# 464118 2013-05-01               21.99                           0.41  Athens
# 464119 2013-06-01               24.55                           0.33  Athens
# 464120 2013-07-01               26.79                           0.27  Athens
# 464121 2013-08-01               27.64                           0.49  Athens
#
# ...

# %%
gr_ath
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 460994 1753-01-01                8.77                           5.13  Athens
# 460995 1753-02-01                8.46                           2.93  Athens
# 460996 1753-03-01               12.95                           2.76  Athens
# 460997 1753-04-01               14.96                           4.85  Athens
# 460998 1753-05-01               20.14                           2.03  Athens
# ...           ...                 ...                            ...     ...
# 464117 2013-04-01               16.95                           0.29  Athens
# 464118 2013-05-01               21.99                           0.41  Athens
# 464119 2013-06-01               24.55                           0.33  Athens
# 464120 2013-07-01               26.79                           0.27  Athens
# 464121 2013-08-01               27.64                           0.49  Athens
#
# ...

# %%
gr_ath_1 = gr_ath[gr_ath['month'] == 1 ]
ath_1 =gr_ath_1.sort_values('year', ascending = True)

# %%
ath_1 = ath_1[(ath_1['dt'] >= datetime(1970, 1, 1)) & (ath_1['dt'] <= datetime(2013, 1, 1))]
ath_1
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 463598 1970-01-01               12.10                           0.25  Athens
# 463610 1971-01-01               12.14                           0.23  Athens
# 463622 1972-01-01               10.04                           0.24  Athens
# 463634 1973-01-01                9.66                           0.34  Athens
# 463646 1974-01-01                8.86                           0.33  Athens
# 463658 1975-01-01                9.80                           0.19  Athens
# 463670 1976-01-01               10.28                           0.25  Athens
# 463682 1977-01-01               10.51                           0.21  Athens
# 463694 1978-01-01                9.93                           0.26  Athens
# 463706 1979-01-01               10.66                           0.31  Athens
# 463718 1980-01-01                9.39                           0.23  Athens
# ...
